# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ** Install YOLOv11 **

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 56.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 126.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 96.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 57.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 835.2 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 103.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.169 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 42.2/112.6 GB disk)

# %% [markdown]
# **# YOLOv11 Training HyperParameters**
#
#
#
# **task**= detect or segment
#
# **mode**= train, val
#
# **model**= path to model file, i.e. yolov8n.pt, yolov8n.yaml
#
# **data**= path to data file dataset.yaml
#
# **epochs**= number of epochs to train for
#
# **imgsz**= size of input images as integer
#
# **batch**= number of images per batch
#
# **projec**t= project traing results saving path
#
# **name**= experiment name

# %%
# !yolo task=detect \
    mode=train \
    model=yolo11m.pt \
    data=/content/drive/MyDrive/ObjectDetection/AnimalDetection/data.yaml \
    epochs=15 \
    imgsz=640 \
    batch=16 \
    project=/content/drive/MyDrive/ObjectDetection/AnimalDetection/TrainingResults \
    name=AnimalDetection
# Out:
# Ultralytics 8.3.169 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !pip install ultralytics --quiet
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
import os
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 18.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 60.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 34.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 36.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 82.3 MB/s eta 0:00:00
# Creating new Ultralytics Settings v0.0.6 file ✅
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !yolo task=detect \
    mode=predict \
    model=/content/drive/MyDrive/ObjectDetection/AnimalDetection/TrainingResults/AnimalDetection2/weights/best.pt \
    source=/content/drive/MyDrive/ObjectDetection/AnimalDetection/Dataset/test/images \
    conf=0.55 \
    line_width=1 \
    project=/content/drive/MyDrive/ObjectDetection/AnimalDetection/DetectionResults \
    name=Test_image_result \
    exist_ok=True
# Out:
# Ultralytics 8.3.169 🚀 Python-3.11.13 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# YOLO11m summary (fused): 125 layers, 20,045,452 parameters, 0 gradients, 67.7 GFLOPs
#
# image 1/200 /content/drive/MyDrive/ObjectDetection/AnimalDetection/Dataset/test/images/100_jpg.rf.a27ee2d854c80fe9d9db621e89eff2ee.jpg: 640x640 1 Bear, 1482.3ms
# image 2/200 /content/drive/MyDrive/ObjectDetection/AnimalDetection/Dataset/test/images/23_jpg.rf.8a7b320d6d7c6046c4c72b8d27355d78.jpg: 640x640 (no detections), 1568.0ms
# image 3/200 /content/drive/MyDrive/ObjectDetection/AnimalDetection/Dataset/test/images/24_jpg.rf.c3435492bc79d4472eb32a81c1b2b93e.jpg: 640x640 1 Bear, 1493.7ms
# image 4/200 /content/drive/MyDrive/ObjectDetection/AnimalDetection/Dataset/test/images/46_jpg.rf.01019f3ca4e7a492e90e6e58f37b319b.jpg: 640x640 1 Bear, 2248.0ms
# image 5/200 /content/drive/MyDrive/ObjectDetection/AnimalDetection/Dataset/test/images/4_jpg.rf.53b1956379993322732a9a615b4b862a.jpg: 640x640 1 Bear, 2270.5ms
# ...

# %%
# !yolo task=detect \
    mode=predict \
    model=/content/drive/MyDrive/ObjectDetection/AnimalDetection/TrainingResults/AnimalDetection2/weights/best.pt \
    source=/content/drive/MyDrive/ObjectDetection/AnimalDetection/TestVideos \
    conf=0.50 \
    line_width=2 \
    project=/content/drive/MyDrive/ObjectDetection/AnimalDetection/DetectionResults \
    name=Wildlife_Detection \
    save=True \
    exist_ok=True
# Out:
# Ultralytics 8.3.169 🚀 Python-3.11.13 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# YOLO11m summary (fused): 125 layers, 20,045,452 parameters, 0 gradients, 67.7 GFLOPs
#
# video 1/1 (frame 1/2632) /content/drive/MyDrive/ObjectDetection/AnimalDetection/TestVideos/VN20250726_234303.mp4: 384x640 1 Tiger, 1078.4ms
# video 1/1 (frame 2/2632) /content/drive/MyDrive/ObjectDetection/AnimalDetection/TestVideos/VN20250726_234303.mp4: 384x640 1 Tiger, 1049.0ms
# video 1/1 (frame 3/2632) /content/drive/MyDrive/ObjectDetection/AnimalDetection/TestVideos/VN20250726_234303.mp4: 384x640 1 Tiger, 920.2ms
# video 1/1 (frame 4/2632) /content/drive/MyDrive/ObjectDetection/AnimalDetection/TestVideos/VN20250726_234303.mp4: 384x640 1 Tiger, 928.8ms
# video 1/1 (frame 5/2632) /content/drive/MyDrive/ObjectDetection/AnimalDetection/TestVideos/VN20250726_234303.mp4: 384x640 1 Tiger, 926.9ms
# ...
